# %%
from langchain_community.llms import tongyi

key = "sk-e958daa80d2a43859e5d69241f58c5d4"

tongyi_llm = tongyi.Tongyi(api_key=key)

tongyi_response = tongyi_llm.invoke("请介绍一下自己")

print(tongyi_response)
# Out:
# 你好！😊 我是通义千问（Qwen），阿里巴巴集团旗下的超大规模语言模型。我能够理解并生成多种语言的文本，比如中文、英文、法语、西班牙语、葡萄牙语、俄语、阿拉伯语、日语、韩语、越南语、泰语、印尼语等，支持全球范围内的多语言交流。
#
# 我的能力包括但不限于：
# 🔹 回答问题：无论是常识、科学、历史、文化，还是日常生活中的小疑问，我都会尽力提供准确、清晰、有依据的回答；
# 🔹 创作文字：写故事、写公文、写邮件、写剧本、逻辑推理、编程，甚至模仿特定风格写作都可以尝试；
# 🔹 表达观点：在符合事实和价值观的前提下，我可以就各类话题提供多角度的分析与见解；
# 🔹 编程辅助：熟悉主流编程语言（如Python、Java、C++、JavaScript等），能解释代码、调试建议、生成函数或算法；
# 🔹 多模态理解（部分版本支持）：例如通过通义万相处理图像生成任务，或结合语音模型实现语音交互（具体取决于你使用的平台版本）。
#
# 需要说明的是：
# ✅ 我不会主动编造信息，对不确定的内容会如实告知；
# ✅ 我尊重事实、遵守法律法规，坚持客观中立，不传播偏见或有害内容；
# ✅ 我没有个人情感、记忆或主观意识——每次对话都是全新的，你的隐私和数据安全也始终被重视（不保存对话记录，除非你所在平台明确说明并获得授权）。
#
# 如果你有任何问题、想法，或者只是想聊聊天、一起头脑风暴，我都非常乐意陪伴你！✨
# 现在，有什么我可以帮你的吗？ 🌟
